# %%
import matplotlib.pyplot as plt

# %matplotlib inline

import pandas as pd

# %% [markdown]
# Here is some data about the population of California since 1900.  What type of graph style makes the most sense?  Use matplotlib to display this data using that graph style.

# %%
pop = [1490000,1550000,1623000,1702000,1792000,1893000,1976000,2054000,2161000,2282000,2406000,2534000,2668000,2811000,2934000,3008000,3071000,3171000,3262000,3339000,3554000,3795000,3991000,4270000,4541000,4730000,4929000,5147000,5344000,5531000,5711000,5824000,5894000,5963000,6060000,6175000,6341000,6528000,6656000,6785000,6950000,7237000,7735000,8506000,8945000,9344000,9559000,9832000,10064000,10337000,10677000,11134000,11635000,12251000,12746000,13133000,13713000,14264000,14880000,15467000,15870000,16497000,17072000,17668000,18151000,18585000,18858000,19176000,19394000,19711000,19971069,20345939,20585469,20868728,21173865,21537849,21935909,22352396,22835958,23256880,23800800,24285933,24820009,25360026,25844393,26441109,27102237,27777158,28464249,29218164,29950111,30414114,30875920,31147208,31317179,31493525,31780829,32217708,32682794,33145121,33987977,34479458,34871843,35253159,35574576,35827943,36021202,36250311,36604337,36961229,37327690,37672654,38019006,38347383,38701278,39032444,39296476,39536653]
year = [1900,1901,1902,1903,1904,1905,1906,1907,1908,1909,1910,1911,1912,1913,1914,1915,1916,1917,1918,1919,1920,1921,1922,1923,1924,1925,1926,1927,1928,1929,1930,1931,1932,1933,1934,1935,1936,1937,1938,1939,1940,1941,1942,1943,1944,1945,1946,1947,1948,1949,1950,1951,1952,1953,1954,1955,1956,1957,1958,1959,1960,1961,1962,1963,1964,1965,1966,1967,1968,1969,1970,1971,1972,1973,1974,1975,1976,1977,1978,1979,1980,1981,1982,1983,1984,1985,1986,1987,1988,1989,1990,1991,1992,1993,1994,1995,1996,1997,1998,1999,2000,2001,2002,2003,2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016,2017]
print(len(pop),len(year))
pop = [i/1e6 for i in pop]
import matplotlib.pyplot as plt

plt.plot(year,pop, c = "k")
plt.xlabel("Year")
plt.ylabel("Population (millions)")
plt.title("California Population Since 1900")
plt.show()
# Out:
# 118 118

# %% [markdown]
# Here is some data on the population of each state in the United States from the 2010 Census.  What graph type makes sense to view the population of each state relative to one another?  Graph the data using that graph style.

# %%
x = [(pop[i],state[i]) for i in range(len(pop))]
x.sort(reverse=True)
x
# Out:
# [(37253956, 'California'),
#  (25145561, 'Texas'),
#  (19378102, 'New York'),
#  (18801310, 'Florida'),
#  (12830632, 'Illinois'),
#  (12702379, 'Pennsylvania'),
#  (11536504, 'Ohio'),
#  (9883640, 'Michigan'),
#  (9687653, 'Georgia'),
#  (9535483, 'North Carolina'),
#  (8791894, 'New Jersey'),
#  (8001024, 'Virginia'),
#  (6724540, 'Washington'),
#  (6547629, 'Massachusetts'),
#  (6483802, 'Indiana'),
#  (6392017, 'Arizona'),
#  (6346105, 'Tennessee'),
#  (5988927, 'Missouri'),
#  (5773552, 'Maryland'),
#  (5686986, 'Wisconsin'),
#  (5303925, 'Minnesota'),
#  (5029196, 'Colorado'),
#  (4779736, 'Alabama'),
#  (4625364, 'South Carolina'),
#  (4533372, 'Louisiana'),
#  (4339367, 'Kentucky'),
#  (3831074, 'Oregon'),
#  (3751351, 'Oklahoma'),
#  (3574097, 'Connecticut'),
#  (3046355, 'Iowa'),
#  (2967297, 'Mississippi'),
#  (2915918, 'Arkansas'),
#  (2853118, 'Kansas'),
#  (2763885, 'Utah'),
#  (2700551, 'Nevada'),
#  (2059179, 'New Mexico'),
#  (1852994, 'West Virginia'),
# ...

# %%
state = ['Alabama','Alaska','Arizona','Arkansas','California','Colorado','Connecticut','Delaware','District of Columbia','Florida','Georgia','Hawaii','Idaho','Illinois','Indiana','Iowa','Kansas','Kentucky','Louisiana','Maine','Maryland','Massachusetts','Michigan','Minnesota','Mississippi','Missouri','Montana','Nebraska','Nevada','New Hampshire','New Jersey','New Mexico','New York','North Carolina','North Dakota','Ohio','Oklahoma','Oregon','Pennsylvania','Rhode Island','South Carolina','South Dakota','Tennessee','Texas','Utah','Vermont','Virginia','Washington','West Virginia','Wisconsin','Wyoming']
pop = [4779736,710231,6392017,2915918,37253956,5029196,3574097,897934,601723,18801310,9687653,1360301,1567582,12830632,6483802,3046355,2853118,4339367,4533372,1328361,5773552,6547629,9883640,5303925,2967297,5988927,989415,1826341,2700551,1316470,8791894,2059179,19378102,9535483,672591,11536504,3751351,3831074,12702379,1052567,4625364,814180,6346105,25145561,2763885,625741,8001024,6724540,1852994,5686986,563626]
print(len(pop),len(state))

state = [x[i][1] for i in range(len(x))]
pop = [x[i][0] for i in range(len(x))]

fig = plt.figure(figsize = (5,7), dpi = 300)
numPts = 10
plt.barh(state[:numPts], pop[:numPts])
plt.title("Population by State")
plt.xlabel("Population")
#plt.ylabel("State")
plt.show()
# Out:
# 51 51

# %% [markdown]
# The data below describes the United States Balance of Trade with other countries, with positive number indicating more export value than import value.  Plot this data using the best graph style.

# %%
years = [1960,1961,1962,1963,1964,1965,1966,1967,1968,1969,1970,1971,1972,1973,1974,1975,1976,1977,1978,1979,1980,1981,1982,1983,1984,1985,1986,1987,1988,1989,1990,1991,1992,1993,1994,1995,1996,1997,1998,1999,2000,2001,2002,2003,2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016,2017]
BalOfTrade = [3508,4195,3370,4210,6022,4664,2939,2604,250,91,2254,-1302,-5443,1900,-4293,12404,-6082,-27246,-29763,-24565,-19407,-16172,-24156,-57767,-109072,-121880,-138538,-151684,-114566,-93141,-80864,-31135,-39212,-70311,-98493,-96384,-104065,-108273,-166140,-258617,-372517,-361509,-418955,-493890,-609885,-714247,-761714,-705376,-708727,-383776,-494661,-548626,-537408,-461135,-489584,-498525,-502001,-552277]
print(len(years),len(BalOfTrade))

fig = plt.figure(figsize = (15,10), dpi = 200)
plt.bar(years, BalOfTrade,)
plt.title("U.S Balance of Trade throughout the Years")
plt.xlabel("Years")
plt.ylabel("Balance of Trade")
plt.show()
# Out:
# 58 58

# %% [markdown]
# The data in the cell below is for US car sales over a number of years for cars, trucks, and total vehicles sales.  Use the best graph type to show all three series on the same graph.

# %%
years = [1931,1933,1935,1937,1939,1941,1951,1953,1955,1957,1959,1961,1963,1964,1965,1966,1967,1968,1969,1970,1971,1972,1973,1974,1975,1976,1977,1978,1979,1980,1981,1982,1983,1984,1985,1986,1987,1988,1989,1990,1991,1992,1993,1994,1995,1996,1997,1998,1999,2000,2001,2002,2003,2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014]
cars = [1903000,1526000,2867000,3508000,2724000,3763000,5164000,5808000,7466000,6033000,6100000,5935000,7720000,8101000,9332000,9028000,8337000,9656000,9582000,8400000,10242000,10940000,11424000,8853000,8624000,10110000,11183000,11314000,10673000,8949235,8489202,7956460,9148038,10323695,10979187,11404239,10191877,10546808,9778517,9303215,8184979,8213113,8517859,8990517,8620159,8478545,8217480,8084989,8637708,8777723,8352000,8042255,7555551,7482555,7659983,7761592,7562334,6769134,5401565,5635739,6089708,7244439,7585341,7687619]
trucks = [328000,261000,552000,645000,521000,902000,1111000,965000,1015000,894000,965000,937000,1270000,1393000,1553000,1636000,1545000,1831000,1970000,1811000,2096000,2629000,3148000,2688000,2478000,3181000,3675000,4109000,3480000,2494378,2288778,2581902,3163478,4159446,4746104,4918782,5001069,5244736,5066744,4846163,4364544,4904331,5680995,6420857,6496166,6977567,7280380,7882298,8777020,9033950,9120378,9096397,9411891,9816018,9784346,9287389,8897981,6724058,5200478,6136787,6951210,7544036,8298102,9154354]
total = [2231000,1787000,3419000,4153000,3245000,4665000,6275000,6773000,8481000,6927000,7065000,6872000,8990000,9494000,10885000,10664000,9882000,11487000,11552000,10211000,12338000,13569000,14572000,11541000,11103000,13291000,14859000,15423000,14153000,11443613,10777980,10538362,12311516,14483141,15725291,16323021,15192946,15791544,14845261,14149378,12549523,13117444,14198854,15411374,15116325,15456112,15497860,15967287,17414728,17811673,17472378,17138652,16967442,17298573,17444329,17048981,16460315,13493192,10602043,11772526,13040918,14788475,15883443,16841973]
print(len(years),len(cars),len(trucks),len(total))

fig = plt.figure(figsize = (7,5), dpi = 100)
ax = fig.add_axes([0,0,1,1])
ax.plot(years, cars, label = "Cars")
ax.plot(years, trucks, label = "Trucks")
ax.plot(years, total, label = "Total")

ax.legend()
plt.show()
# Out:
# 64 64 64 64

# %% [markdown]
# The data below reflects the favorite ice cream flavors of some people who were surveyed.  Create a frequency histogram.  Then, create a Pareto Diagram.

# %%
ic = ['chocolate', 'strawberry', 'vanilla', 'rum raisin', 'chocolate', 'vanilla', 'vanilla', 'strawberry', 'rum raisin', 'chocolate', 'strawberry', 'cotton candy', 'chocolate', 'vanilla', 'rum raisin', 'vanilla', 'vanilla', 'strawberry', 'chocolate', 'vanilla', 'chocolate', 'vanilla', 'strawberry', 'vanilla', 'chocolate', 'chocolate', 'purple cow', 'chocolate', 'rum raisin', 'vanilla', 'chocolate', 'bubble gum', 'vanilla']

# %%
ic = pd.Series(ic)

# %%
ic.value_counts()
# Out:
# vanilla         11
# chocolate       10
# strawberry       5
# rum raisin       4
# bubble gum       1
# purple cow       1
# cotton candy     1
# dtype: int64

# %%
icf = ['vanilla','chocolate','strawberry', 'rum raisin', 'bubble gum', 'purple cow', 'cotton candy']
data = []       # create an empty Python list; sublists will be appended for each boxplot
for icecream in ic:
    data.append(ic)
data_min = min([min(sublist) for sublist in data])  # this and the following 3 lines automatically size the graph to the data 
data_max = max([max(sublist) for sublist in data])  # while providing buffer space

fig, ax = plt.subplots()


""" Alternate method for adjusting the figure size """
fig.set_figheight(5)
fig.set_figwidth(7)
#fig.add_axes

ax.boxplot(data)

ax.set_ylim(data_min - 2, data_max + 2)
ax.set_xticklabels(icf)
ax.set_ylabel('Frequency')
ax.set_xlabel('Ice Cream')
ax.set_xticks(range(1,len(instructors)+1),instructors)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-95-1b38942b477d> in <module>
#      14 #fig.add_axes
#      15
# ---> 16 ax.boxplot(data)
#      17
#      18 ax.set_ylim(data_min - 2, data_max + 2)
#
# ~\Anaconda3\lib\site-packages\matplotlib\__init__.py in inner(ax, data, *args, **kwargs)
#    1808                         "the Matplotlib list!)" % (label_namer, func.__name__),
#    1809                         RuntimeWarning, stacklevel=2)
# -> 1810             return func(ax, *args, **kwargs)
#    1811
#    1812         inner.__doc__ = _add_data_doc(inner.__doc__,
#
# ...
